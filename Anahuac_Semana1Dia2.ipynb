# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/Universidad_anahuac_fullstack_modulo1_desarrollo_python/blob/main/Anahuac_Semana1Dia2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
P = "Python"
print(P[0:2])
print(P[2:])
print(P[:2])
# Out:
# Py
# thon
# Py

# %%
print("¿Cómo te llamas?")
Nombre = input()
print("Gusto en conocerte", Nombre)
# Out:
# ¿Cómo te llamas?
# Augusto
# Gusto en conocerte Augusto

# %% [markdown]
# Funciones de string

# %%
Nombre = " Augusto|Lorenzo|Gassós "
print(Nombre.strip())
print(len(Nombre))
print(Nombre.upper())
print(Nombre.count('o'))
print(Nombre.replace('o','x'))
print(Nombre.split("|"))
print(Nombre.upper())
print(Nombre + " eres un chingón")
print(Nombre.title())
# Out:
# Augusto|Lorenzo|Gassós
# 24
#  AUGUSTO|LORENZO|GASSÓS
# 3
#  Augustx|Lxrenzx|Gassós
# [' Augusto', 'Lorenzo', 'Gassós ']
#  AUGUSTO|LORENZO|GASSÓS
#  Augusto|Lorenzo|Gassós  eres un chingón
#  Augusto|Lorenzo|Gassós

# %% [markdown]
# Cast - Convesión de variables

# %%
Edad = input("Escibe tu edad: ")
EdadNumero = int(Edad)
print(EdadNumero, type(EdadNumero))
# Out:
# Escibe tu edad: 15
# 15 <class 'int'>

# %% [markdown]
# Estructuras de datos
# Listas, diccionarios, tuplas

# %%
#Listas
Lista = ["Augusto",59,"Masculino"]
Lista1 = ["Juan",57,"Masculino"]
Lista
Lista[2]
print(Lista[1] + 1)
Lista.append("Informática")
print(Lista)
Lista[3]="Licenciatura en Informática"
print(Lista)
Lista2 = Lista + Lista1
print(Lista2)
print(len(Lista))
print("Augusto" in Lista)
print("Juan" in Lista1)
Lista.insert(2,"Insertado")
print(Lista)

#Diccionario {Clave: valor}
Diccionario = {1:"hola",2:"Mundo"}
print(Diccionario[1])
print(Diccionario[2])
Diccionario1 = {"Nombres":["Augusto","Juan"], "Edad":[59,57] }
print(Diccionario1["Edad"])
print(Diccionario1["Edad"][0])
print(Diccionario1.keys())
print(Diccionario1.values())

#Tuplas
Tupla = (1,2,3,4,5)
print(Tupla)
# Out:
# 60
# ['Augusto', 59, 'Masculino', 'Informática']
# ['Augusto', 59, 'Masculino', 'Licenciatura en Informática']
# ['Augusto', 59, 'Masculino', 'Licenciatura en Informática', 'Juan', 57, 'Masculino']
# 4
# True
# True
# ['Augusto', 59, 'Insertado', 'Masculino', 'Licenciatura en Informática']
# hola
# Mundo
# [59, 57]
# 59
# dict_keys(['Nombres', 'Edad'])
# dict_values([['Augusto', 'Juan'], [59, 57]])
# (1, 2, 3, 4, 5)
