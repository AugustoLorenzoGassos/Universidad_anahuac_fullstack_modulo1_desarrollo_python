# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/Universidad_anahuac_fullstack_modulo1_desarrollo_python/blob/main/Anahuac_primer_notebook_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Montamos el Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("drive/MyDrive/ARPI_MONTREAL_2023/data")
# !ls
# Out:
# catboost_info					      days_and_hours.pdf
# Data_sample_v2_adobe_datafeed_web_april_may_2023.csv  grafico.pdf
# Data_simplify_1_account_created.csv

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# # Tipos de variable

# %%
x = 3

# %%
type(x)
# Out:
# int

# %%
y = 7.1

# %%
type(y)
# Out:
# float

# %%
z1 = "True"

# %%
z2 = 'Hola que tal'

# %%
type(z1)
type(z2)
# Out:
# str

# %%
# Out:
# str

# %%
W = False

# %%
type(W)
# Out:
# bool

# %% [markdown]
# # Asignacion

# %%
mario = 375678

# %%
mario
# Out:
# 375678

# %%
print(mario)
# Out:
# 375678

# %%
mario1 = mario2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3208842533.py in <cell line: 0>()
# ----> 1 mario1 = mario2
#
# NameError: name 'mario2' is not defined

# %%
mario1 = mario

# %%
mario1
# Out:
# 375678

# %%
mario = 12345

# %%
mario
# Out:
# 12345

# %%
mario1
# Out:
# 375678

# %%
a = 1
b = 2
c = 3
z = 4

# %%
a, b, c, z = 1, 2, 3, 4

# %%
print(a)
print(b)
print(c)
print(z)
# Out:
# 1
# 2
# 3
# 4

# %%
a = 0
b = 0
c = 0
z = 0

# %%
a = b = c = z = 0

# %%
print(a)
print(b)
print(c)
print(z)
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# # Tipado dinamico

# %%
mario = 123
type(mario)
# Out:
# int

# %%
mario = "Hola mundo"
type(mario)
# Out:
# str

# %% [markdown]
# puedo seguir usando el mismo nombre de variables para distintivos tipos de variables

# %%
mario + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-867236896.py in <cell line: 0>()
# ----> 1 mario + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(mario) + 3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1252388412.py in <cell line: 0>()
# ----> 1 int(mario) + 3
#
# ValueError: invalid literal for int() with base 10: 'Hola mundo'

# %%
mario = "555"

# %%
mario+3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-370690242.py in <cell line: 0>()
# ----> 1 mario+3
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(mario)+3
# Out:
# 558

# %% [markdown]
# # Palabras reservadas
# No puedo usar estas palabras

# %%
False = 3
# Out:
#   File "/tmp/ipython-input-3257230105.py", line 1
#     False = 3
#     ^
# SyntaxError: cannot assign to False

# %%
false = 3

# %%
print(false)
type(false)
# Out:
# 3
# int

# %%
for = 555
# Out:
#   File "/tmp/ipython-input-1168541788.py", line 1
#     for = 555
#         ^
# SyntaxError: invalid syntax

# %%
For = 555

# %%
print(For)
type(For)
# Out:
# 555
# int

# %% [markdown]
# # Operadores

# %% [markdown]
# ## operadores aritmeticos

# %%
# Esto es un comentario 3+3

# %%
variable1 = 3
variable2 = 5

# %%
# Suma
variable1 + variable2
# Out:
# 8

# %%
# resta
variable1 - variable2
# Out:
# -2

# %%
# resta
variable2 - variable1
# Out:
# 2

# %%
# Multiplicacion
variable1 * variable2
# Out:
# 15

# %%
# potencia 3^5
variable1 ** variable2
# Out:
# 243

# %%
# potencia 3^5
variable2 ** variable1
# Out:
# 125

# %%
3^5
# Out:
# 6

# %%
x = 3
y = -2
y = x*y
x = x**2
print("y=", y)
print("x=", x)
# Out:
# y= -6
# x= 9

# %%
x *= y

# %%
x
# Out:
# -54

# %%
x = x*y

# %%
x
# Out:
# -54

# %% [markdown]
# ## Operadores de comparacion

# %%
x = 54
y = 6
print(x)
print(y)
# Out:
# 54
# 6

# %%
x < y
# Out:
# False

# %%
z = x < y

# %%
print(z)
# Out:
# False

# %%
x == y
# Out:
# False

# %%
54 == 6
# Out:
# False

# %%
6 == 6
# Out:
# True

# %%
6 = 6
# Out:
#   File "/tmp/ipython-input-33114681.py", line 1
#     6 = 6
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x != b
# Out:
# True

# %%
54 != 6
# Out:
# True

# %%
6 != 6
# Out:
# False

# %%
x = 4
print("Es x mayor o igual a 4?", x >= 4)
print("x es menor a 3?", x<3)
# Out:
# Es x mayor o igual a 4? True
# x es menor a 3? False

# %% [markdown]
# ## Operadores logicos

# %%
x = 17
print(x)
# Out:
# 17

# %%
x > 5
# Out:
# True

# %%
x < 7
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
y =  x > 5 and x < 7
print(y)
# Out:
# False

# %%
z = x > 5 or x < 7
print(z)
# Out:
# True

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
k = not x > 5
print(k)
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ## Operador modulo

# %%
5/3
# Out:
# 1.6666666666666667

# %%
5%3
# Out:
# 2

# %%
48 % 2
# Out:
# 0

# %%
49 % 2
# Out:
# 1

# %%
x = 27
y = 9
print(x % y)
# Out:
# 0

# %%
27/9
# Out:
# 3.0

# %% [markdown]
# ## Prioridad de operaciones

# %%
(3+4) * (5-7) < 67 and 10%3 == (6-4)**3+1
# Out:
# False

# %%
(3+4) * (5-7)
# Out:
# -14

# %%
3+4 * 5-7
# Out:
# 16

# %%
3+(4 * 5)-7
# Out:
# 16

# %%
(6-4)**3+1
# Out:
# 9

# %%
2**3+1
# Out:
# 9

# %%
2**3
# Out:
# 8

# %%
2**3+1
# Out:
# 9

# %%
6-4**3+1
# Out:
# -57

# %%
6-(4**3)+1
# Out:
# -57
