# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/Universidad_anahuac_fullstack_modulo1_desarrollo_python/blob/main/Anahuac_Semana3D%C3%ADa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Entorno virtual

# %%
archivo = open("archivo.txt", "a")
archivo.close()

# %%
archivo = open("archivo.txt", "w")
archivo.write("Diplomado Anahuac\n")
archivo.write("Python\n")
archivo.close()

# %%
archivo = open("archivo.txt", "r")
for linea in archivo:
  print(linea)
archivo.close()
# Out:
# Diplomado Anahuac
#
# Python
