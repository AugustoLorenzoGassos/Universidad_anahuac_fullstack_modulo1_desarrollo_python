# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoLorenzoGassos/Universidad_anahuac_fullstack_modulo1_desarrollo_python/blob/main/Anahuac_Entornos_virtuales_y_Submodulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entornos virtuales y Submodulos

# %% [markdown]
# ##**Ejercicio 1 — Crear y activar entorno virtual**
#
# Objetivo: comprender aislamiento de dependencias.
#
# Instrucciones
#
# 1. Crear carpeta proyecto_ventas
#
# 2. Crear entorno virtual:
#
#     `python -m venv venv`
#
# 3. Activarlo:
#
#     Windows:
#
#     `venv\Scripts\activate`
#
#     Mac/Linux:
#
#     `source venv/bin/activate`
#
# 4. Verificar que pip list está vacío (o casi vacío)

# %% [markdown]
# * ¿Entiende que el entorno aísla dependencias?
#
# * ¿Sabe activarlo/desactivarlo?

# %% [markdown]
# ##**Ejercicio 2 — Instalación y congelación de dependencias**
#
# 1. Instalar pandas:
#
# `pip install pandas`
#
# 2. Generar archivo:
#
# `pip freeze > requirements.txt`
#
# 3. Eliminar entorno.
#
# 4. Recrearlo e instalar dependencias con:
#
# `pip install -r requirements.txt`

# %% [markdown]
# * Comprensión de *requirements.txt*
#
# * Reproducibilidad del entorno

# %% [markdown]
# ##**Ejercicio 3 — Crear paquete propio**
#
# Estructura requerida:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **submodulos y funciones:**
# `ventas/calculos.py`
#
# * función `calcular_total(precio, cantidad)`
#
# * función `calcular_descuento(total, porcentaje)`
#
#
# `ventas/utilidades.py`
#
# * función `validar_numero(valor)`
#
# * función `fecha_actual()` usando `datetime`
#
# `ventas/reportes.py`
#
# * función `generar_dataframe(datos)` usando `pandas`
#
# * función `resumen_ventas(df)`

# %% [markdown]
# **Imports absolutos**
# En `main.py`:
#
# ```
# from ventas.calculos import calcular_total
# from ventas.reportes import generar_dataframe
# ```

# %% [markdown]
# * ¿Funciona correctamente?
#
# * ¿Entiende el path del paquete?

# %% [markdown]
# **Imports relativos**
# Dentro de `reportes.py`, usar import relativo:
# `from .calculos import calcular_total`

# %% [markdown]
# * ¿Por qué no funciona si ejecuta reportes.py directamente?
#
# * ¿Qué significa ejecutar como módulo?

# %% [markdown]
# Porque el archivo esta en la misma carpeta

# %% [markdown]
# Ejecutar correctamente con:
# `python -m ventas.reportes`

# %% [markdown]
# **Uso de __init__.py**
# Modificar ventas/__init__.py:
# `from .calculos import calcular_total`

# %% [markdown]
# Ahora permitir:
# `from ventas import calcular_total`

# %% [markdown]
# * ¿Entiende que __init__.py controla qué se exporta?

# %%
ENrtiendo que funciona como un archivo de configuración. En MVC con Visual Studio existe un comcepto que se llama "layout" donde se cargan todas las referencias de archivos de estilo y librerias que se vayan a usar
